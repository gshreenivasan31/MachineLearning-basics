# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area, df.price, color = 'red',marker = '+')
plt.show()

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df[["area"]],df.price,color="red")
plt.plot(df[["area"]],reg.predict(df[["area"]]),color= "blue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[80], line 5
#       3 plt.ylabel("price")
#       4 plt.scatter(df[["area"]],df.price,color="red")
# ----> 5 plt.plot(df[["area"]],reg.predict(df[["area"]]),color= "blue")
#       6 plt.show()
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# ...

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
135.78767123*3300 +180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict([[5000]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
df = pd.read_csv("areas.csv")

# %%
p = reg .predict(df[["area"]])

# %%
df["price"] = p

# %%
df.to_csv("answer.csv")

# %%
d = pd.read_csv("canada_per_capita_income.csv")
d.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline
plt.xlabel("year")
plt.ylabel("per capita")
plt.scatter(d.year,d['per capita income (US$)'])
plt.show()

# %%
rek = linear_model.LinearRegression()

# %%
rek.fit(d[["year"]],d["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
rek.predict([[2020]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
rek.predict([[1974]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3179.30063417])

# %%
# %matplotlib inline
plt.xlabel("year")
plt.ylabel("per capita")
plt.scatter(d.year,d['per capita income (US$)'])
plt.plot(d.year, rek.predict(d[["year"]]),color='red')
plt.show()

# %%
import pickle

# %%
with open("model_pickle","wb") as f:
    pickle.dump(reg,f)

# %%
with  open("model_pickle","rb") as f:
    rok = pickle.load(f)

# %%
rok.predict([[5000]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])
